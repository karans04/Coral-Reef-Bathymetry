# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
#importing required packages
from bs4 import BeautifulSoup
import os
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import rasterio
import numpy as np
from rasterio import plot
import math
from datetime import datetime

#machine learning packages 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

#plotting packages
from matplotlib.colors import ListedColormap
from matplotlib import cm
from matplotlib.colors import BoundaryNorm
import matplotlib as mpl
import matplotlib.pylab as plt
import seaborn as sns
import matplotlib.gridspec as gridspec
from matplotlib.lines import Line2D
from matplotlib.patches import Rectangle
from matplotlib import patches

# %%
from rasterio import mask
import rasterio

# %%
os.chdir('../')

# %%
#importing other python files 
import src.Tide_API as tide
import src.Depth_profile as depth
import src.Pixel_transformation as pt
import src.Sentinel2_image as s2

# %%
import src.Coral_Reef as coral_reef

# %%
reef = coral_reef.Coral_Reef('data', 'Nasau')
reef.create_directories()

# %%
coords = reef.get_bounding_box()

# %%
s = s2.Sentinel2_image('data/Nasau/S2A_MSIL2A_20190401T220921_N0211_R129_T01KCV_20190402T001930.SAFE', coords)
# Out:
# (-178.53760600090027, -18.755206591925898, -178.4115636348724, -18.62375715561433)
# <class 'tuple'>

# %%
s.meta
# Out:
# {'dt': datetime.datetime(2019, 4, 1, 22, 11, 7),
#  'crs': 'epsg:32701',
#  'rows': 10980,
#  'cols': 10980,
#  'ulx': 300000,
#  'uly': 8000020,
#  'xdim': 10,
#  'ydim': -10}

# %%
imgs,m = s.load_sentinel()

# %%
train = pt.get_regressor(reef,s)
# Out:
# /Users/ksunil/Desktop/Karan/Codebase/src/Pixel_transformation.py:33: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(fp)

# %%
meta = s.get_meta()

# %%
meta['ydim']
# Out:
# -10

# %%
#method to get just the pixel values of our bounding box
def get_pixel_val(coord):
#     print(coord)
#     print(int((coord.x - meta['ulx'])))
#     print(int((coord.y - meta['uly'])))
# #     print(meta)
    x_index = int((coord.x - meta['ulx']) // meta['xdim'])
    y_index = int((coord.y - meta['uly']) // abs(meta['ydim']))
    print(x_index, y_index)
    return [data[0][y_index][x_index] for data in imgs]

#extracts the different band values for our image
def extract_pixel_cols(df):
#     print(df.x.min(), df.y.min())
#     print()
    df['Pixels'] = df.Coordinates.apply(get_pixel_val)
    df['b2'] = df.Pixels.apply(lambda x: (x[0]))
    df['b3'] = df.Pixels.apply(lambda x: (x[1]))
    df['b8'] = df.Pixels.apply(lambda x: (x[3]))
    #converts points with pixel values above the mask to nan
    df['mask'] = df.b8.apply(lambda x: x if x < meta['mask_thresh'] else np.nan)
    return df

# %%
img = imgs[0]

# %%
extract_pixel_cols(train)
# Out:
# 338784.29945154116 7926918.114314989
#
# POINT (344881.3061437146 7926918.114314989)
# 7077
# 1262
# 707 126
# POINT (344886.3414090239 7926973.496594012)
# 7082
# 1318
# 708 131
# POINT (344891.3767183681 7927028.878866606)
# 7087
# 1373
# 708 137
# POINT (344896.4120717457 7927084.261132771)
# 7093
# 1429
# 709 142
# POINT (344901.4474691557 7927139.643392509)
# 7098
# 1484
# 709 148
# POINT (344906.4829105967 7927195.025645817)
# 7103
# 1539
# 710 153
# POINT (344911.518396065 7927250.407892698)
# 7108
# 1595
# 710 159
# POINT (344916.5539255674 7927305.79013315)
# 7113
# 1650
# 711 165
# POINT (344921.5894990917 7927361.172367176)
# 7118
# 1706
# 711 170
# POINT (344926.6251166478 7927416.554594773)
# 7123
# 1761
# 712 176
# POINT (344931.6607782208 7927471.936815943)
# 7128
# 1816
# 712 181
# POINT (344936.6964838203 7927527.319030684)
# 7133
# 1872
# 713 187
# POINT (344941.7322334476 7927582.701238999)
# 7138
# 1927
# 713 192
# POINT (344946.7680270937 7927638.083440888)
# ...

# %%
train.x.min()
# Out:
# 338784.29945154116

# %%
train.x.max()
# Out:
# 345445.5293005221

# %%
train.y.min()
# Out:
# 7926918.114314989

# %%
train.y.max()
# Out:
# 7940111.008630554

# %%
from rasterio.warp import reproject

# %%
fig,ax = plt.subplots()
rasterio.plot.show(imgs[2], cmap='Blues')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
rreproject()

# %%
nasau = pd.read_csv('data/Nasau/Training_data/Nasau_out_20190307221104.csv')

# %%
nasau.head()
# Out:
#    Unnamed: 0    Height      diff     b2     b3              x             y
# 0           0 -8.220236  0.640848  298.0  157.0  344881.312298  7.926918e+06
# 1           1 -8.220236  0.746908  363.0  172.0  344886.347402  7.926973e+06
# 2           2 -6.722689  0.375124  422.0  290.0  344891.382551  7.927029e+06
# 3           4 -1.318878  0.023484  517.0  505.0  344901.452980  7.927140e+06
# 4           5 -1.118805  0.032088  475.0  460.0  344906.488260  7.927195e+06

# %%
y = nasau.loc[:,['diff']]
x = nasau.loc[:,['Height']]

# %%
from sklearn import linear_model
reg = linear_model.HuberRegressor()
#     reg = LinearRegression()
reg.fit(x,y)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# HuberRegressor(alpha=0.0001, epsilon=1.35, fit_intercept=True, max_iter=100,
#         tol=1e-05, warm_start=False)

# %%
m = reg.coef_[0]
c = reg.intercept_
line = lambda x: (x-c) /m

# %%
fig, ax = plt.subplots()
sns.scatterplot(x = 'diff', y = 'Height', data = nasau)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt

# %%
s.get_metadata()
# Out:
# (-178.53760600090027, -18.755206591925898, -178.4115636348724, -18.62375715561433)
# <class 'tuple'>
# {'dt': datetime.datetime(2019, 4, 1, 22, 11, 7),
#  'crs': 'epsg:32701',
#  'rows': 10980,
#  'cols': 10980,
#  'ulx': 300000,
#  'uly': 8000020,
#  'xdim': 10,
#  'ydim': -10}

# %%
nasau_gjson = s.read_gjson()

# %%
nasau_gjson['geometry']
# Out:
# 0    POLYGON ((337803.4093075963 7938692.573454551,...
# Name: geometry, dtype: object

# %%
imgs[0].meta
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-8f2f9e7c7f28> in <module>
# ----> 1 imgs[0].meta
#
# AttributeError: 'numpy.ndarray' object has no attribute 'meta'

# %%
from pathlib import Path

# %%
datum = pt.all_safe_files('data','Moce')
# Out:
# 0.432
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# mse train  0.018295258546815074
# mse test  0.01879520963921927
# -0.085
# /Users/ksunil/Desktop/Karan/Codebase/src/Pixel_transformation.py:111: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(fp)
# /anaconda3/lib/python3.7/site-packages/rasterio/__init__.py:216: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# ...

# %%
import glob
from pathlib import Path
from matplotlib import 
os.getcwd()
# Out:
# '/Users/ksunil/Desktop/Karan/Codebase/notebooks'

# %%
import statsmodels.api as sm 
import pylab as py

# %%
moce_train = os.path.join('data','Moce','Training_data')

# %%
def linear_relationship(data):
    return data['Height'].corr(data['diff'])

# %%
def multivariate_normal(data):
    sm.qqplot(data[['Height','diff']], line ='45') 
    py.show()

# %%
for fn in os.listdir(moce_train):
    df = pd.read_csv(moce_train + '/' + fn)
    print(linear_relationship(df))
    multivariate_normal(df)

# %%
data_points = np.random.normal(0, 1, 100)

# %%
df
# Out:
#      Unnamed: 0    Height      diff      b2      b3              x  \
# 0             0 -8.739236  0.212561    47.0    38.0  344881.307416
# 1             1 -8.739236  0.450201    80.0    51.0  344886.342589
# 2             2 -7.241689  0.067252   123.0   115.0  344891.377805
# 3             3 -2.760444 -0.312683   158.0   216.0  344896.413065
# 4             4 -1.837878 -0.358634   153.0   219.0  344901.448369
# 5             5 -1.637805 -0.423814   180.0   275.0  344906.483717
# 6             6 -1.332110 -0.639443   153.0   290.0  344911.519110
# 7             7 -2.105018 -0.188197   198.0   239.0  344916.554546
# 8             8 -1.524508 -0.453256   143.0   225.0  344921.590026
# 9             9 -1.869435 -0.487191   137.0   223.0  344926.625550
# 10           10 -1.645514 -0.527586   213.0   361.0  344931.661119
# 11           11 -1.898532 -0.588974   187.0   337.0  344936.696731
# 12           12 -1.373857 -0.658056   203.0   392.0  344941.732388
# ...
