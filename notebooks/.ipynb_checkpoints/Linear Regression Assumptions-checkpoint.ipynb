# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir('../')

# %%
#importing other python files 
import src.Tide_API as tide
import src.Depth_profile as depth
import src.Pixel_transformation as pt

# %%
datum = pt.all_safe_files('data','Moce')
# Out:
# 0.432
# /Users/ksunil/Desktop/Karan/Codebase/src/Pixel_transformation.py:111: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(fp)
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# mse train  4094.310433731111
# mse test  2888.0218122749097
# -0.085
# /Users/ksunil/Desktop/Karan/Codebase/src/Pixel_transformation.py:111: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(fp)
# ...

# %%
def fit_polyfit(df):
    x = df['diff']
    y = df['Height']
    z = np.polyfit(x,y,2)
    print(z)
    f = np.poly1d(z)
    print(f)

# %%
fit_polyfit(datum['S2A_MSIL1C_20160327T221002_N0204_R129_T01KCV_20160327T220957.SAFE'][2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6cf4c249aabe> in <module>
# ----> 1 fit_polyfit(datum['S2A_MSIL1C_20160327T221002_N0204_R129_T01KCV_20160327T220957.SAFE'][2])
#
# <ipython-input-16-57571c0772de> in fit_polyfit(df)
#       2     x = df['diff']
#       3     y = df['Height']
# ----> 4     z = np.polyfit(x,y,2)
#       5     print(z)
#       6     f = np.poly1d(z)
#
# NameError: name 'np' is not defined

# %%
def linear_relationship(data):
    return data['Height'].corr(data['diff'])

# %%
for k,v in datum.items():
    print(linear_relationship(v[2]))
# Out:
# -0.8190606273678498
# 0.3287977747961887
# -0.7918235020245044
# -0.8415687289350146
# 0.04990691951150693
# -0.8270889002174358
# -0.8127173997964123
# -0.7779330068265047
# -0.8099261758379596
# -0.8655166424937145
# -0.48305083480878797
# -0.22554861989325478
# -0.7186790530534355
# -0.7779464986759573
# -0.3100121003072981

# %%
for k,v in datum.items():
    r = v[0]
    d = v[2]
    residual = d['Height'] - r(d['diff'])
    fig, ax = plt.subplots()
    sns.distplot(residual)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-69fcd52a3d5e> in <module>
#       2     r = v[0]
#       3     d = v[2]
# ----> 4     residual = d['Height'] - r(d['diff'])
#       5     fig, ax = plt.subplots()
#       6     sns.distplot(residual)
#
# ~/Desktop/Karan/Codebase/src/Pixel_transformation.py in <lambda>(x)
#     246
#     247     c = reg.intercept_
# --> 248     line = lambda x: (x-c) /m if (x-c)/m <=10 and (x-c)/m >= -20 else np.nan
#     249
#     250
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ...

# %%
datum['S2A_MSIL1C_20160327T221002_N0204_R129_T01KCV_20160327T220957.SAFE'][2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-f87b68aed5b0> in <module>
# ----> 1 datum['S2A_MSIL1C_20160327T221002_N0204_R129_T01KCV_20160327T220957.SAFE'][2]
#
# KeyError: 'S2A_MSIL1C_20160327T221002_N0204_R129_T01KCV_20160327T220957.SAFE'

# %%
for k,v in datum.items():
    r = v[0]
    d = v[2]
    predicted = d['diff'].apply(r)
    
    
    residual = d['Height'] - predicted 
    fig, ax = plt.subplots()
    sns.residplot(predicted, residual, lowess=True)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Residual')
